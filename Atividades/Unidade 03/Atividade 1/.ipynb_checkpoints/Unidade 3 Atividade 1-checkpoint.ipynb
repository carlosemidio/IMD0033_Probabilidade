# %% [markdown]
# # Descrição I
# Criar gráficos Z-Score com a probabilidade da área em verde similar a figura ao lado e relacionado com as notas da primeira, segunda, terceira unidades e média final das disciplinas:
#
#     ○ FMC I, FMC II e Probabilidade do BTI
#     ○ Para testes, escolha as notas 5.0, 7.0 e 9.0
#     ○ Utilizar os dados disponibilizados em dados.ufrn.br

# %%
import pandas as pd

# Lendo o dataset de componentes curriculares
componentes = pd.read_csv('componentes-curriculares-presenciais.csv', sep=';')
componentes.head()
# Out:
#    id_componente tipo_componente  codigo nivel  \
# 0          18642      DISCIPLINA  MUT721     T
# 1          18643      DISCIPLINA  MUT508     T
# 2          18644      DISCIPLINA  MUT516     T
# 3          18645      DISCIPLINA  MUT520     T
# 4          18646      DISCIPLINA  MUT165     T
#
#                                nome unidade_responsavel  ch_teorico  \
# 0             LABORATÓRIOS ELETIVOS    ESCOLA DE MÚSICA          60
# 1  COMPOSIÇÃO EM MÚSICA POPULAR III    ESCOLA DE MÚSICA          60
# 2                      CO-REPETIÇÃO    ESCOLA DE MÚSICA          30
# 3            CONTRABAIXO ACÚSTICO I    ESCOLA DE MÚSICA          30
# 4              PIANO COMPLEMENTAR I    ESCOLA DE MÚSICA          15
#
#    ch_pratico  ch_estagio  ch_total       ...         ementa  bibliografia  \
# 0           0           0        60       ...            NaN           NaN
# 1           0           0        60       ...            NaN           NaN
# ...

# %%
turmas = list()
# Lendo os datasets de todas as turmas de 2013.1 à 2017.2
for i in range(3, 8):
    str_dataset_1 = 'turmas-201' + str(i) +'.1.csv'
    str_dataset_2 = 'turmas-201' + str(i) +'.2.csv'
    turmas.append(pd.read_csv(str_dataset_1, sep=';'))
    turmas.append(pd.read_csv(str_dataset_2, sep=';'))
    
turmas_total = pd.concat(turmas)
turmas_total.columns

# %%
alunos = list()

# Lendo os datasets de matriculas de alunos nas turmas de 2013.1 à 2017.2
for i in range(3, 8):
    str_dataset_1 = 'matriculas-de-201' + str(i) +'.1.csv'
    str_dataset_2 = 'matriculas-de-201' + str(i) +'.2.csv'
    alunos.append(pd.read_csv(str_dataset_1, sep=';'))
    alunos.append(pd.read_csv(str_dataset_2, sep=';'))
    
alunos_total = pd.concat(alunos)
alunos_total.columns

# %%
alunos = list()

# Lendo os datasets de matriculas de alunos nas turmas de 2013.1 à 2017.2
for i in range(3, 8):
    str_dataset_1 = 'matriculas-de-201' + str(i) +'.1.csv'
    str_dataset_2 = 'matriculas-de-201' + str(i) +'.2.csv'
    alunos.append(pd.read_csv(str_dataset_1, sep=';'))
    alunos.append(pd.read_csv(str_dataset_2, sep=';'))
    
alunos_total = pd.concat(alunos)
alunos_total.columns

# %%
imd_unidade = 'INSTITUTO METROPOLE DIGITAL'
dim_unidade = 'DEPARTAMENTO DE INFORMÁTICA E MATEMÁTICA APLICADA'
prob_nome = 'PROBABILIDADE'
fmc1_nome = 'FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO I'
fmc2_nome = 'FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO II'

# Filtrando os id's das turmas de probabilidade, fmc1 e fmc2
id_comp_prob = list(componentes[(componentes.nome == prob_nome) & ((componentes.unidade_responsavel == imd_unidade) | (componentes.unidade_responsavel == dim_unidade))]['id_componente'])
id_comp_fmc1 = list(componentes[(componentes.nome == fmc1_nome) & ((componentes.unidade_responsavel == imd_unidade) | (componentes.unidade_responsavel == dim_unidade))]['id_componente'])
id_comp_fmc2 = list(componentes[(componentes.nome == fmc2_nome) & ((componentes.unidade_responsavel == imd_unidade) | (componentes.unidade_responsavel == dim_unidade))]['id_componente'])
id_comp_fmc2

# %%
turmas_prob = list()
turmas_fmc1 = list()
turmas_fmc2 = list()

# Utilizando dos id's das turmas para colher os dados sobre as turmas
for id_prob in id_comp_prob:
    turmas_prob.append(turmas_total[(turmas_total.id_componente_curricular == id_prob) & (turmas_total.situacao_turma == 'CONSOLIDADA')])

for id_fmc1 in id_comp_fmc1:
    turmas_fmc1.append(turmas_total[(turmas_total.id_componente_curricular == id_fmc1) & (turmas_total.situacao_turma == 'CONSOLIDADA')])

for id_fmc2 in id_comp_fmc2:
    turmas_fmc2.append(turmas_total[(turmas_total.id_componente_curricular == id_fmc2) & (turmas_total.situacao_turma == 'CONSOLIDADA')])
    
turmas_prob = list(int(i) for i in pd.concat(turmas_prob)['id_turma'].unique())
turmas_fmc1 = list(int(i) for i in pd.concat(turmas_fmc1)['id_turma'].unique())
turmas_fmc2 = list(int(i) for i in pd.concat(turmas_fmc2)['id_turma'].unique())

turmas_fmc2

# %%
alunos_prob = list()
alunos_fmc1 = list()
alunos_fmc2 = list()

for id_turma_prob in turmas_prob:
    alunos_prob.append(alunos_total[alunos_total.id_turma == id_turma_prob])

for id_turma_fmc1 in turmas_fmc1:
    alunos_fmc1.append(alunos_total[alunos_total.id_turma == id_turma_fmc1])

for id_turma_fmc2 in turmas_fmc2:
    alunos_fmc2.append(alunos_total[alunos_total.id_turma == id_turma_fmc2])
    
alunos_prob = pd.concat(alunos_prob)
alunos_prob = alunos_prob[alunos_prob['media_final'].notnull()]

alunos_fmc1 = pd.concat(alunos_fmc1)
alunos_fmc1 = alunos_fmc1[alunos_fmc1['media_final'].notnull()]

alunos_fmc2 = pd.concat(alunos_fmc2)
alunos_fmc2 = alunos_fmc2[alunos_fmc2['media_final'].notnull()]
alunos_fmc2.head()

# %%
# Separando em unidades
un1_prob = alunos_prob[alunos_prob.unidade == 1]
un2_prob = alunos_prob[alunos_prob.unidade == 2]
un3_prob = alunos_prob[alunos_prob.unidade == 3]

un1_fmc1 = alunos_fmc1[alunos_fmc1.unidade == 1]
un2_fmc1 = alunos_fmc1[alunos_fmc1.unidade == 2]
un3_fmc1 = alunos_fmc1[alunos_fmc1.unidade == 3]

un1_fmc2 = alunos_fmc2[alunos_fmc2.unidade == 1]
un2_fmc2 = alunos_fmc2[alunos_fmc2.unidade == 2]
un3_fmc2 = alunos_fmc2[alunos_fmc2.unidade == 3]
un3_fmc2.head()

# %%
# Calculando as medias das unidades e a final
media_un1_prob = un1_prob['nota'].mean()
media_un2_prob = un2_prob['nota'].mean()
media_un3_prob = un3_prob['nota'].mean()
media_final_prob = alunos_prob['media_final'].mean()

media_un1_fmc1 = un1_fmc1['nota'].mean()
media_un2_fmc1 = un2_fmc1['nota'].mean()
media_un3_fmc1 = un3_fmc1['nota'].mean()
media_final_fmc1 = alunos_fmc1['media_final'].mean()

media_un1_fmc2 = un1_fmc2['nota'].mean()
media_un2_fmc2 = un2_fmc2['nota'].mean()
media_un3_fmc2 = un3_fmc2['nota'].mean()
media_final_fmc2 = alunos_fmc2['media_final'].mean()
media_final_fmc2

# %%
# Calculando os desvios padroes
std_un1_prob = un1_prob['nota'].std()
std_un2_prob = un2_prob['nota'].std()
std_un3_prob = un3_prob['nota'].std()
std_final_prob = alunos_prob['media_final'].std()

std_un1_fmc1 = un1_fmc1['nota'].std()
std_un2_fmc1 = un2_fmc1['nota'].std()
std_un3_fmc1 = un3_fmc1['nota'].std()
std_final_fmc1 = alunos_fmc1['media_final'].std()

std_un1_fmc2 = un1_fmc2['nota'].std()
std_un2_fmc2 = un2_fmc2['nota'].std()
std_un3_fmc2 = un3_fmc2['nota'].std()
std_final_fmc2 = alunos_fmc2['media_final'].std()

print("Prob - Un1:", std_un1_prob,"Un2:", std_un2_prob,"Un3:", std_un3_prob, "MF:", std_final_prob)
print("FMC I - Un1:", std_un1_fmc1,"Un2:", std_un2_fmc1,"Un3:", std_un3_fmc1, "MF:", std_final_fmc2)
print("FMC II - Un1:", std_un1_fmc2,"Un2:", std_un2_fmc2,"Un3:", std_un3_fmc2, "MF:", std_final_fmc2)

# %%
# Definindo os marcadores
un1_prob_markers = [media_un1_prob - 2*std_un1_prob, media_un1_prob - std_un1_prob,
                   media_un1_prob + std_un1_prob, media_un1_prob + 2*std_un1_prob]
un1_prob_markers =[int(i) for i in un1_prob_markers if((i >= 0) & (i < 10))]

un2_prob_markers = [media_un2_prob - 2*std_un2_prob, media_un2_prob - std_un2_prob,
                   media_un2_prob + std_un2_prob, media_un2_prob + 2*std_un2_prob]
un2_prob_markers =[int(i) for i in un2_prob_markers if((i >= 0) & (i < 10))]

un3_prob_markers = [media_un3_prob - 2*std_un3_prob, media_un3_prob - std_un3_prob,
                   media_un3_prob + std_un3_prob, media_un3_prob + 2*std_un3_prob]
un3_prob_markers =[int(i) for i in un3_prob_markers if((i >= 0) & (i < 10))]

mf_prob_markers = [media_final_prob - 2*std_final_prob, media_final_prob - std_final_prob,
                   media_final_prob + std_final_prob, media_final_prob + 2*std_final_prob]
mf_prob_markers =[int(i) for i in mf_prob_markers if((i >= 0) & (i < 10))]

un1_fmc1_markers = [media_un1_fmc1 - 2*std_un1_fmc1, media_un1_fmc1 - std_un1_fmc1,
                   media_un1_fmc1 + std_un1_fmc1, media_un1_fmc1 + 2*std_un1_fmc1]
un1_fmc1_markers =[int(i) for i in un1_fmc1_markers if((i >= 0) & (i < 10))]

un2_fmc1_markers = [media_un2_fmc1 - 2*std_un2_fmc1, media_un2_fmc1 - std_un2_fmc1,
                   media_un2_fmc1 + std_un2_fmc1, media_un2_fmc1 + 2*std_un2_fmc1]
un2_fmc1_markers =[int(i) for i in un2_fmc1_markers if((i >= 0) & (i < 10))]

un3_fmc1_markers = [media_un3_fmc1 - 2*std_un3_fmc1, media_un3_fmc1 - std_un3_fmc1,
                   media_un3_fmc1 + std_un3_fmc1, media_un3_fmc1 + 2*std_un3_fmc1]
un3_fmc1_markers =[int(i) for i in un3_fmc1_markers if((i >= 0) & (i < 10))]

mf_fmc1_markers = [media_final_fmc1 - 2*std_final_fmc1, media_final_fmc1 - std_final_fmc1,
                   media_final_fmc1 + std_final_fmc1, media_final_fmc1 + 2*std_final_fmc1]
mf_fmc1_markers =[int(i) for i in mf_fmc1_markers if((i >= 0) & (i < 10))]


un1_fmc2_markers = [media_un1_fmc2 - 2*std_un1_fmc2, media_un1_fmc2 - std_un1_fmc2,
                   media_un1_fmc2 + std_un1_fmc2, media_un1_fmc2 + 2*std_un1_fmc2]
un1_fmc2_markers =[int(i) for i in un1_fmc2_markers if((i >= 0) & (i < 10))]

un2_fmc2_markers = [media_un2_fmc2 - 2*std_un2_fmc2, media_un2_fmc2 - std_un2_fmc2,
                   media_un2_fmc2 + std_un2_fmc2, media_un2_fmc2 + 2*std_un2_fmc2]
un2_fmc2_markers =[int(i) for i in un2_fmc2_markers if((i >= 0) & (i < 10))]

un3_fmc2_markers = [media_un3_fmc2 - 2*std_un3_fmc2, media_un3_fmc2 - std_un3_fmc2,
                   media_un3_fmc2 + std_un3_fmc2, media_un3_fmc2 + 2*std_un3_fmc2]
un3_fmc2_markers =[int(i) for i in un3_fmc2_markers if((i >= 0) & (i < 10))]

mf_fmc2_markers = [media_final_fmc2 - 2*std_final_fmc2, media_final_fmc2 - std_final_fmc2,
                   media_final_fmc2 + std_final_fmc2, media_final_fmc2 + 2*std_final_fmc2]
mf_fmc2_markers =[int(i) for i in mf_fmc2_markers if((i >= 0) & (i < 10))]

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Criando os atributos dos gráficos
eixo_x = range(0, 10)
xi = [9, 7, 5]
cdf9_un1_prob = stats.norm.cdf(xi[0], media_un1_prob, std_un1_prob)
cdf7_un1_prob = stats.norm.cdf(xi[1], media_un1_prob, std_un1_prob)
cdf5_un1_prob = stats.norm.cdf(xi[2], media_un1_prob, std_un1_prob)

cdf9_un2_prob = stats.norm.cdf(xi[0], media_un2_prob, std_un2_prob)
cdf7_un2_prob = stats.norm.cdf(xi[1], media_un2_prob, std_un2_prob)
cdf5_un2_prob = stats.norm.cdf(xi[2], media_un2_prob, std_un2_prob)

cdf9_un3_prob = stats.norm.cdf(xi[0], media_un3_prob, std_un3_prob)
cdf7_un3_prob = stats.norm.cdf(xi[1], media_un3_prob, std_un3_prob)
cdf5_un3_prob = stats.norm.cdf(xi[2], media_un3_prob, std_un3_prob)

cdf9_mf_prob = stats.norm.cdf(xi[0], media_final_prob, std_final_prob)
cdf7_mf_prob = stats.norm.cdf(xi[1], media_final_prob, std_final_prob)
cdf5_mf_prob = stats.norm.cdf(xi[2], media_final_prob, std_final_prob)

pdf_un1_prob = stats.norm.pdf(eixo_x, media_un1_prob, std_un1_prob)

pdf_un2_prob = stats.norm.pdf(eixo_x, media_un2_prob, std_un2_prob)

pdf_un3_prob = stats.norm.pdf(eixo_x, media_un3_prob, std_un3_prob)

pdf_mf_prob = stats.norm.pdf(eixo_x, media_final_prob, std_final_prob)

fig = plt.figure(figsize=(20,12))

ax1 = fig.add_subplot(4,4,1)
ax2 = fig.add_subplot(4,4,2)
ax3 = fig.add_subplot(4,4,3)
ax4 = fig.add_subplot(4,4,4)

ax5 = fig.add_subplot(4,4,5)
ax6 = fig.add_subplot(4,4,6)
ax7 = fig.add_subplot(4,4,7)
ax8 = fig.add_subplot(4,4,8)

ax9 = fig.add_subplot(4,4,9)
ax10 = fig.add_subplot(4,4,10)
ax11 = fig.add_subplot(4,4,11)
ax12 = fig.add_subplot(4,4,12)

ax1.set_title("Unidade1 z-score para 9");
ax2.set_title("Unidade2 z-score para 9");
ax3.set_title("Unidade3  z-score para 9");
ax4.set_title("Média final  z-score para 9");

ax5.set_title("Unidade1 z-score para 7");
ax6.set_title("Unidade2 z-score para 7");
ax7.set_title("Unidade3  z-score para 7");
ax8.set_title("Média final  z-score para 7");

ax9.set_title("Unidade1 z-score para 5");
ax10.set_title("Unidade2 z-score para 5");
ax11.set_title("Unidade3  z-score para 5");
ax12.set_title("Média final  z-score para 5");

ax1.plot(eixo_x, pdf_un1_prob, '-bD',markevery=un1_prob_markers)

ax1.fill_between(eixo_x[0:xi[0]], pdf_un1_prob[0:xi[0]],color='g',alpha=.5)

ax2.plot(eixo_x, pdf_un2_prob, '-bD',markevery=un2_prob_markers)

ax2.fill_between(eixo_x[0:xi[0]], pdf_un2_prob[0:xi[0]],color='g',alpha=.5)

ax3.plot(eixo_x, pdf_un3_prob, '-bD',markevery=un3_prob_markers)

ax3.fill_between(eixo_x[0:xi[0]], pdf_un3_prob[0:xi[0]],color='g',alpha=.5)

ax4.plot(eixo_x, pdf_mf_prob, '-bD',markevery=mf_prob_markers)

ax4.fill_between(eixo_x[0:xi[0]], pdf_mf_prob[0:xi[0]],color='g',alpha=.5)


ax5.plot(eixo_x, pdf_un1_prob, '-bD',markevery=un1_prob_markers)
ax5.fill_between(eixo_x[0:xi[1]], pdf_un1_prob[0:xi[1]],color='g',alpha=.5)
ax6.plot(eixo_x, pdf_un2_prob, '-bD',markevery=un2_prob_markers)
ax6.fill_between(eixo_x[0:xi[1]], pdf_un2_prob[0:xi[1]],color='g',alpha=.5)
ax7.plot(eixo_x, pdf_un3_prob, '-bD',markevery=un3_prob_markers)
ax7.fill_between(eixo_x[0:xi[1]], pdf_un3_prob[0:xi[1]],color='g',alpha=.5)
ax8.plot(eixo_x, pdf_mf_prob, '-bD',markevery=mf_prob_markers)
ax8.fill_between(eixo_x[0:xi[1]], pdf_mf_prob[0:xi[1]],color='g',alpha=.5)

ax9.plot(eixo_x, pdf_un1_prob, '-bD',markevery=un1_prob_markers)
ax9.fill_between(eixo_x[0:xi[2]], pdf_un1_prob[0:xi[2]],color='g',alpha=.5)
ax10.plot(eixo_x, pdf_un2_prob, '-bD',markevery=un2_prob_markers)
ax10.fill_between(eixo_x[0:xi[2]], pdf_un2_prob[0:xi[2]],color='g',alpha=.5)
ax11.plot(eixo_x, pdf_un3_prob, '-bD',markevery=un3_prob_markers)
ax11.fill_between(eixo_x[0:xi[2]], pdf_un3_prob[0:xi[2]],color='g',alpha=.5)
ax12.plot(eixo_x, pdf_mf_prob, '-bD',markevery=mf_prob_markers)
ax12.fill_between(eixo_x[0:xi[2]], pdf_mf_prob[0:xi[2]],color='g',alpha=.5)


plt.tight_layout()

plt.suptitle("Z-scores probabilidade", fontsize=20, y=1.09);

plt.show()

print(cdf5_mf_prob)

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Criando os atributos dos gráficos
eixo_x = range(0, 10)
xi = [9, 7, 5]
cdf9_un1_fmc1 = stats.norm.cdf(xi[0], media_un1_fmc1, std_un1_fmc1)
cdf7_un1_fmc1 = stats.norm.cdf(xi[1], media_un1_fmc1, std_un1_fmc1)
cdf5_un1_fmc1 = stats.norm.cdf(xi[2], media_un1_fmc1, std_un1_fmc1)

cdf9_un2_fmc1 = stats.norm.cdf(xi[0], media_un2_fmc1, std_un2_fmc1)
cdf7_un2_fmc1 = stats.norm.cdf(xi[1], media_un2_fmc1, std_un2_fmc1)
cdf5_un2_fmc1 = stats.norm.cdf(xi[2], media_un2_fmc1, std_un2_fmc1)

cdf9_un3_fmc1 = stats.norm.cdf(xi[0], media_un3_fmc1, std_un3_fmc1)
cdf7_un3_fmc1 = stats.norm.cdf(xi[1], media_un3_fmc1, std_un3_fmc1)
cdf5_un3_fmc1 = stats.norm.cdf(xi[2], media_un3_fmc1, std_un3_fmc1)

cdf9_mf_fmc1 = stats.norm.cdf(xi[0], media_final_fmc1, std_final_fmc1)
cdf7_mf_fmc1 = stats.norm.cdf(xi[1], media_final_fmc1, std_final_fmc1)
cdf5_mf_fmc1 = stats.norm.cdf(xi[2], media_final_fmc1, std_final_fmc1)

pdf_un1_fmc1 = stats.norm.pdf(eixo_x, media_un1_fmc1, std_un1_fmc1)

pdf_un2_fmc1 = stats.norm.pdf(eixo_x, media_un2_fmc1, std_un2_fmc1)

pdf_un3_fmc1 = stats.norm.pdf(eixo_x, media_un3_fmc1, std_un3_fmc1)

pdf_mf_fmc1 = stats.norm.pdf(eixo_x, media_final_fmc1, std_final_fmc1)

fig = plt.figure(figsize=(20,12))

ax1 = fig.add_subplot(4,4,1)
ax2 = fig.add_subplot(4,4,2)
ax3 = fig.add_subplot(4,4,3)
ax4 = fig.add_subplot(4,4,4)

ax5 = fig.add_subplot(4,4,5)
ax6 = fig.add_subplot(4,4,6)
ax7 = fig.add_subplot(4,4,7)
ax8 = fig.add_subplot(4,4,8)

ax9 = fig.add_subplot(4,4,9)
ax10 = fig.add_subplot(4,4,10)
ax11 = fig.add_subplot(4,4,11)
ax12 = fig.add_subplot(4,4,12)

ax1.set_title("Unidade1 z-score para 9");
ax2.set_title("Unidade2 z-score para 9");
ax3.set_title("Unidade3  z-score para 9");
ax4.set_title("Média final  z-score para 9");

ax5.set_title("Unidade1 z-score para 7");
ax6.set_title("Unidade2 z-score para 7");
ax7.set_title("Unidade3  z-score para 7");
ax8.set_title("Média final  z-score para 7");

ax9.set_title("Unidade1 z-score para 5");
ax10.set_title("Unidade2 z-score para 5");
ax11.set_title("Unidade3  z-score para 5");
ax12.set_title("Média final  z-score para 5");

ax1.plot(eixo_x, pdf_un1_fmc1, '-bD',markevery=un1_fmc1_markers)

ax1.fill_between(eixo_x[0:xi[0]], pdf_un1_fmc1[0:xi[0]],color='g',alpha=.5)

ax2.plot(eixo_x, pdf_un2_fmc1, '-bD',markevery=un2_fmc1_markers)

ax2.fill_between(eixo_x[0:xi[0]], pdf_un2_fmc1[0:xi[0]],color='g',alpha=.5)

ax3.plot(eixo_x, pdf_un3_fmc1, '-bD',markevery=un3_fmc1_markers)

ax3.fill_between(eixo_x[0:xi[0]], pdf_un3_fmc1[0:xi[0]],color='g',alpha=.5)

ax4.plot(eixo_x, pdf_mf_fmc1, '-bD',markevery=mf_fmc1_markers)

ax4.fill_between(eixo_x[0:xi[0]], pdf_mf_fmc1[0:xi[0]],color='g',alpha=.5)

ax5.plot(eixo_x, pdf_un1_fmc1, '-bD',markevery=un1_fmc1_markers)
ax5.fill_between(eixo_x[0:xi[1]], pdf_un1_fmc1[0:xi[1]],color='g',alpha=.5)
ax6.plot(eixo_x, pdf_un2_fmc1, '-bD',markevery=un2_fmc1_markers)
ax6.fill_between(eixo_x[0:xi[1]], pdf_un2_fmc1[0:xi[1]],color='g',alpha=.5)
ax7.plot(eixo_x, pdf_un3_fmc1, '-bD',markevery=un3_fmc1_markers)
ax7.fill_between(eixo_x[0:xi[1]], pdf_un3_fmc1[0:xi[1]],color='g',alpha=.5)
ax8.plot(eixo_x, pdf_mf_fmc1, '-bD',markevery=mf_fmc1_markers)
ax8.fill_between(eixo_x[0:xi[1]], pdf_mf_fmc1[0:xi[1]],color='g',alpha=.5)

ax9.plot(eixo_x, pdf_un1_fmc1, '-bD',markevery=un1_fmc1_markers)
ax9.fill_between(eixo_x[0:xi[2]], pdf_un1_fmc1[0:xi[2]],color='g',alpha=.5)
ax10.plot(eixo_x, pdf_un2_fmc1, '-bD',markevery=un2_fmc1_markers)
ax10.fill_between(eixo_x[0:xi[2]], pdf_un2_fmc1[0:xi[2]],color='g',alpha=.5)
ax11.plot(eixo_x, pdf_un3_fmc1, '-bD',markevery=un3_fmc1_markers)
ax11.fill_between(eixo_x[0:xi[2]], pdf_un3_fmc1[0:xi[2]],color='g',alpha=.5)
ax12.plot(eixo_x, pdf_mf_fmc1, '-bD',markevery=mf_fmc1_markers)
ax12.fill_between(eixo_x[0:xi[2]], pdf_mf_fmc1[0:xi[2]],color='g',alpha=.5)


plt.tight_layout()

plt.suptitle("Z-scores fmc1", fontsize=20, y=1.09);

plt.show()

print(cdf5_mf_fmc1)

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Criando os atributos dos gráficos
eixo_x = range(0, 10)
xi = [9, 7, 5]
cdf9_un1_fmc2 = stats.norm.cdf(xi[0], media_un1_fmc2, std_un1_fmc2)
cdf7_un1_fmc2 = stats.norm.cdf(xi[1], media_un1_fmc2, std_un1_fmc2)
cdf5_un1_fmc2 = stats.norm.cdf(xi[2], media_un1_fmc2, std_un1_fmc2)

cdf9_un2_fmc2 = stats.norm.cdf(xi[0], media_un2_fmc2, std_un2_fmc2)
cdf7_un2_fmc2 = stats.norm.cdf(xi[1], media_un2_fmc2, std_un2_fmc2)
cdf5_un2_fmc2 = stats.norm.cdf(xi[2], media_un2_fmc2, std_un2_fmc2)

cdf9_un3_fmc2 = stats.norm.cdf(xi[0], media_un3_fmc2, std_un3_fmc2)
cdf7_un3_fmc2 = stats.norm.cdf(xi[1], media_un3_fmc2, std_un3_fmc2)
cdf5_un3_fmc2 = stats.norm.cdf(xi[2], media_un3_fmc2, std_un3_fmc2)

cdf9_mf_fmc2 = stats.norm.cdf(xi[0], media_final_fmc2, std_final_fmc2)
cdf7_mf_fmc2 = stats.norm.cdf(xi[1], media_final_fmc2, std_final_fmc2)
cdf5_mf_fmc2 = stats.norm.cdf(xi[2], media_final_fmc2, std_final_fmc2)

pdf_un1_fmc2 = stats.norm.pdf(eixo_x, media_un1_fmc2, std_un1_fmc2)

pdf_un2_fmc2 = stats.norm.pdf(eixo_x, media_un2_fmc2, std_un2_fmc2)

pdf_un3_fmc2 = stats.norm.pdf(eixo_x, media_un3_fmc2, std_un3_fmc2)

pdf_mf_fmc2 = stats.norm.pdf(eixo_x, media_final_fmc2, std_final_fmc2)

fig = plt.figure(figsize=(20,12))

ax1 = fig.add_subplot(4,4,1)
ax2 = fig.add_subplot(4,4,2)
ax3 = fig.add_subplot(4,4,3)
ax4 = fig.add_subplot(4,4,4)

ax5 = fig.add_subplot(4,4,5)
ax6 = fig.add_subplot(4,4,6)
ax7 = fig.add_subplot(4,4,7)
ax8 = fig.add_subplot(4,4,8)

ax9 = fig.add_subplot(4,4,9)
ax10 = fig.add_subplot(4,4,10)
ax11 = fig.add_subplot(4,4,11)
ax12 = fig.add_subplot(4,4,12)

ax1.set_title("Unidade1 z-score para 9");
ax2.set_title("Unidade2 z-score para 9");
ax3.set_title("Unidade3  z-score para 9");
ax4.set_title("Média final  z-score para 9");

ax5.set_title("Unidade1 z-score para 7");
ax6.set_title("Unidade2 z-score para 7");
ax7.set_title("Unidade3  z-score para 7");
ax8.set_title("Média final  z-score para 7");

ax9.set_title("Unidade1 z-score para 5");
ax10.set_title("Unidade2 z-score para 5");
ax11.set_title("Unidade3  z-score para 5");
ax12.set_title("Média final  z-score para 5");

ax1.plot(eixo_x, pdf_un1_fmc2, '-bD',markevery=un1_fmc2_markers)

ax1.fill_between(eixo_x[0:xi[0]], pdf_un1_fmc2[0:xi[0]],color='g',alpha=.5)

ax2.plot(eixo_x, pdf_un2_fmc2, '-bD',markevery=un2_fmc2_markers)

ax2.fill_between(eixo_x[0:xi[0]], pdf_un2_fmc2[0:xi[0]],color='g',alpha=.5)

ax3.plot(eixo_x, pdf_un3_fmc2, '-bD',markevery=un3_fmc2_markers)

ax3.fill_between(eixo_x[0:xi[0]], pdf_un3_fmc2[0:xi[0]],color='g',alpha=.5)

ax4.plot(eixo_x, pdf_mf_fmc2, '-bD',markevery=mf_fmc2_markers)

ax4.fill_between(eixo_x[0:xi[0]], pdf_mf_fmc2[0:xi[0]],color='g',alpha=.5)


ax5.plot(eixo_x, pdf_un1_fmc2, '-bD',markevery=un1_fmc2_markers)
ax5.fill_between(eixo_x[0:xi[1]], pdf_un1_fmc2[0:xi[1]],color='g',alpha=.5)
ax6.plot(eixo_x, pdf_un2_fmc2, '-bD',markevery=un2_fmc2_markers)
ax6.fill_between(eixo_x[0:xi[1]], pdf_un2_fmc2[0:xi[1]],color='g',alpha=.5)
ax7.plot(eixo_x, pdf_un3_fmc2, '-bD',markevery=un3_fmc2_markers)
ax7.fill_between(eixo_x[0:xi[1]], pdf_un3_fmc2[0:xi[1]],color='g',alpha=.5)
ax8.plot(eixo_x, pdf_mf_fmc2, '-bD',markevery=mf_fmc2_markers)
ax8.fill_between(eixo_x[0:xi[1]], pdf_mf_fmc2[0:xi[1]],color='g',alpha=.5)

ax9.plot(eixo_x, pdf_un1_fmc2, '-bD',markevery=un1_fmc2_markers)
ax9.fill_between(eixo_x[0:xi[2]], pdf_un1_fmc2[0:xi[2]],color='g',alpha=.5)
ax10.plot(eixo_x, pdf_un2_fmc2, '-bD',markevery=un2_fmc2_markers)
ax10.fill_between(eixo_x[0:xi[2]], pdf_un2_fmc2[0:xi[2]],color='g',alpha=.5)
ax11.plot(eixo_x, pdf_un3_fmc2, '-bD',markevery=un3_fmc2_markers)
ax11.fill_between(eixo_x[0:xi[2]], pdf_un3_fmc2[0:xi[2]],color='g',alpha=.5)
ax12.plot(eixo_x, pdf_mf_fmc2, '-bD',markevery=mf_fmc2_markers)
ax12.fill_between(eixo_x[0:xi[2]], pdf_mf_fmc2[0:xi[2]],color='g',alpha=.5)


plt.tight_layout()

plt.suptitle("Z-scores fmc2", fontsize=20, y=1.09);

plt.show()

print(cdf5_mf_fmc2)

# %% [markdown]
# # Descrição II
# Fazer um gráfico similar ao da figura do documento, onde o eixo X são as médias dos alunos que cursaram a disciplina FMC I e o eixo Y as médias dos alunos que cursaram FMC II para toda a série histórica presente em dados.ufrn.br

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


alunos_fmc1_min = alunos_fmc1.head(len(alunos_fmc2))
alunos_fmc = pd.DataFrame()
alunos_fmc['FMC1'] = alunos_fmc1_min['media_final']
alunos_fmc['FMC2'] = alunos_fmc2['media_final'].values
sns.jointplot(x='FMC1', y ='FMC2', data=alunos_fmc)
plt.show()

# %% [markdown]
# ## Análise
#
# O gráfico apresenta uma maior densidade nos valores baixos, o que demonstra que é comum os alunos não conseguirem um bom desempenho nas duas disciplinas. Também é possível reparar que os pontos não se alinham nas diagonais, o que mostra uma correlação baixa entre o desempenho entre nas duas matérias.
