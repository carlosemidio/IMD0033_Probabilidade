# %%
import pandas as pd

# turmas 2017.1
turmas = pd.read_csv('turmas-2012.1.csv', sep=';')

# matriculas em componentes
notas = pd.read_csv('discentes-2012.csv', sep=';')

# %%
# verificando os dados das turmas
print(turmas.columns)
turmas.head()
# Out:
# Index(['id_turma', 'codigo_turma', 'id_docente_interno', 'id_docente_externo',
#        'observacao', 'id_componente_curricular', 'nivel_ensino',
#        'campus_turma', 'local', 'ano', 'periodo', 'data_inicio', 'data_fim',
#        'descricao_horario', 'total_solicitacoes', 'capacidade_aluno', 'tipo',
#        'distancia', 'data_consolidacao', 'agrupadora', 'id_turma_agrupadora',
#        'qtd_aulas_lancadas', 'situacao_turma', 'convenio',
#        'modalidade_participantes', 'Unnamed: 25'],
#       dtype='object')
#    id_turma codigo_turma  id_docente_interno  id_docente_externo  \
# 0  57593168           01             26652.0                 NaN
# 1  57593169           02             21707.0                 NaN
# 2  57593170           01             21707.0                 NaN
# 3  57593172           01           5752921.0                 NaN
# 4  57593173           01           5752917.0                 NaN
#
#                                           observacao  \
# ...

# %%
# verificando os dados dos componentes curriculares
print(notas.columns)
notas.head()
# Out:
# Index(['id_componente', 'tipo_componente', 'codigo', 'nivel', 'nome',
#        'unidade_responsavel', 'ch_teorico', 'ch_pratico', 'ch_estagio',
#        'ch_total', 'ch_dedicada_docente', 'ch_ead', 'ementa', 'bibliografia',
#        'equivalencia', 'pre_requisito', 'co_requisito', 'objetivos',
#        'conteudo', 'competencias_habilidades', 'referencias', 'ano_programa',
#        'periodo_programa', 'procedimentos_avaliacao', 'modalidade',
#        'curso_componente'],
#       dtype='object')
#    id_componente tipo_componente  codigo nivel  \
# 0          18642      DISCIPLINA  MUT721     T
# 1          18643      DISCIPLINA  MUT508     T
# 2          18644      DISCIPLINA  MUT516     T
# 3          18645      DISCIPLINA  MUT520     T
# 4          18646      DISCIPLINA  MUT165     T
#
#                                nome unidade_responsavel  ch_teorico  \
# 0             LABORATÓRIOS ELETIVOS    ESCOLA DE MÚSICA          60
# ...

# %%
# filtrando as turmas com código IMD
turmas_imd = turmas[turmas.codigo.str.contains("IMD0033")]

# utilizar apenas disciplinas com código "CONSOLIDADA"
turmas_imd = turmas_imd[turmas_imd.situacao_turma == 'CONSOLIDADA']

# resetar os idexes
turmas_imd.reset_index(drop=True, inplace=True)

# visualizar o novo dataset
turmas_imd.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-81354ec42f5f> in <module>()
#       1 # filtrando as turmas com código IMD
# ----> 2 turmas_imd = turmas[turmas.codigo.str.contains("IMD0033")]
#       3
#       4 # utilizar apenas disciplinas com código "CONSOLIDADA"
#       5 turmas_imd = turmas_imd[turmas_imd.situacao_turma == 'CONSOLIDADA']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'codigo'
